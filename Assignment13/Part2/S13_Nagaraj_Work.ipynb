# %% [markdown]
# <a href="https://colab.research.google.com/github/nravinuthala/EVA4.0/blob/master/Assignment13/Part2/S13_Nagaraj_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# !git clone https://github.com/nravinuthala/YoloV3
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 988, done.
# remote: Counting objects: 100% (988/988), done.
# remote: Compressing objects: 100% (939/939), done.
# remote: Total 988 (delta 20), reused 988 (delta 20), pack-reused 0
# Receiving objects: 100% (988/988), 28.46 MiB | 20.57 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# !cd /content

# %%
# !rm -rf YoloV3

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls weights
# Out:
# ls: cannot access 'weights': No such file or directory

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-25 17:39:22.419973: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (96 found, 317 missing, 2 empty, 0 duplicate, for 450 images): 100% 450/450 [00:00<00:00, 37109.71it/s]
# Caching images (0.3GB): 100% 450/450 [00:02<00:00, 217.04it/s]
# Reading image shapes: 100% 450/450 [00:00<00:00, 4221.21it/s]
# ...

# %%
cp weights/last.pt weights/last_doraemon.pt

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/450 data/customdata/images/01DM_b.jpg: 384x512 1 doraemons, Done. (0.039s)
# image 2/450 data/customdata/images/0_15ce0a1f-4ee0-4f35-95db-8bc042822519.jpg: 448x512 Done. (0.036s)
# image 3/450 data/customdata/images/110581262-phetcharburi-thailand-august-14-2018-soft-focus-on-cartoon-model-doraemon-and-nobita-from-doraemon-s.jpg: 384x512 1 doraemons, Done. (0.032s)
# ...

# %%
Image(filename='out_out/doraemon-minimal-4k_68164_3840x2160.jpg', width=600)

# %%
#images60.jpg
Image(filename='out_out/images5_1.jpg', width=600)
#Image(filename='out_out/a4227575367_10.jpg', width=600)
#Image(filename='out_out/doraemon-kumkum-puzzle-354405.1.jpg', width=600)
#Image(filename='out_out/01DM_b.jpg', width=600)

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_doraemon_videos/output" --source "/content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon1.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_doraemon_videos/output', save_txt=False, source='/content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon1.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/715) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon1.mp4: 384x512 Done. (0.040s)
# video 1/1 (2/715) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon1.mp4: 384x512 Done. (0.038s)
# video 1/1 (3/715) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon1.mp4: 384x512 Done. (0.038s)
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_doraemon_videos/output" --source "/content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon2.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_doraemon_videos/output', save_txt=False, source='/content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon2.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/718) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon2.mp4: 384x512 Done. (0.039s)
# video 1/1 (2/718) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon2.mp4: 384x512 Done. (0.038s)
# video 1/1 (3/718) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon2.mp4: 384x512 Done. (0.037s)
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/yolo_doraemon_videos/output" --source "/content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon4.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/yolo_doraemon_videos/output', save_txt=False, source='/content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon4.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/675) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon4.mp4: 320x512 1 doraemons, Done. (0.034s)
# video 1/1 (2/675) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon4.mp4: 320x512 1 doraemons, Done. (0.033s)
# video 1/1 (3/675) /content/gdrive/My Drive/yolo_doraemon_videos/input/doraemon4.mp4: 320x512 Done. (0.031s)
# ...
